# %% [markdown]
# <a href="https://colab.research.google.com/github/HyeJeongIm/BP_Project/blob/main/%08BPv1_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import h5py # HDF5를 이용하면 대량의 NumPy 데이터 등을 손쉽게 관리할 수 있다.

from tensorflow.keras import activations
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import sys
import tensorflow.compat.v1 as tf
import tensorflow.keras as keras
# from tensorflow.python.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam, SGD, Adagrad,Adadelta, Nadam
from sklearn.preprocessing import StandardScaler

from tensorflow.keras.layers import Activation, BatchNormalization, Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D,Conv1D, Dense, MaxPooling2D,MaxPooling1D,GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
import numpy as np
from scipy import io
from sklearn.model_selection import train_test_split

from keras.utils import np_utils
np.random.seed(7)

print('Python version : ', sys.version)
print('TensorFlow version : ', tf.__version__)
print('Keras version : ', keras.__version__)

import numpy as np
import tensorflow as tf
import random

import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout
# Out:
# Python version :  3.7.13 (default, Apr 24 2022, 01:04:09)
# [GCC 7.5.0]
# TensorFlow version :  2.8.2
# Keras version :  2.8.0

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
from scipy import io

# 데이터 파일 불러오기
train_data = io.loadmat('/content/gdrive/MyDrive/BP/data/train_feature.mat')
test_data = io.loadmat('/content/gdrive/MyDrive/BP/data/test_after_feature.mat')

X_train = train_data['data']
X_test = test_data['data']

sbp_train = train_data['sbp_total'] # 수축기
sbp_test = test_data['sbp_total']
dbp_train = train_data['dbp_total'] # 이완기
dbp_test = test_data['dbp_total']

# %%
import pandas as pd

df_train_raw = pd.DataFrame(X_train)
df_train_raw.head(103)
# 0: area
# 1: st
# 2: dt
# 3: 
# 4:
# 5:
# 6:
# 7:
# 8:
# 9: bpm
# 10: 나이
# 11: 키
# 12: 몸무게
# 13: 성별
# Out:
#              0         1         2         3         4         5         6   \
# 0    337.416745  0.176250  0.638750  0.523750  0.323750  0.151250  0.642500
# 1    257.321639  0.183750  0.457500  0.353125  0.198125  0.123125  0.473750
# 2    249.801359  0.168750  0.433750  0.337500  0.203125  0.125000  0.451875
# 3    250.852644  0.171250  0.447500  0.348125  0.196250  0.121250  0.463125
# 4    249.526044  0.168750  0.470000  0.363750  0.191250  0.115000  0.477500
# ..          ...       ...       ...       ...       ...       ...       ...
# 98   291.119448  0.186250  0.673125  0.504375  0.188750  0.096875  0.628750
# 99   301.255091  0.186875  0.680000  0.500625  0.193125  0.104375  0.625625
# 100  332.521091  0.242500  0.696250  0.503750  0.216250  0.130000  0.663750
# 101  346.043612  0.263750  0.722500  0.526875  0.225000  0.135000  0.686250
# 102  358.117266  0.288750  0.741875  0.546250  0.230625  0.137500  0.713750
#
#            7         8           9        10      11     12   13
# 0    0.417500  0.217500   76.212471  53.0082  148.65  48.65  0.0
# 1    0.293125  0.193750   96.551724  53.0082  148.65  48.65  0.0
# 2    0.292500  0.191250  102.689487  53.0082  148.65  48.65  0.0
# 3    0.286875  0.187500   99.762470  53.0082  148.65  48.65  0.0
# 4    0.282500  0.181250   96.774194  53.0082  148.65  48.65  0.0
# ..        ...       ...         ...      ...     ...    ...  ...
# 98   0.283125  0.163750   71.090047  53.0082  148.65  48.65  0.0
# 99   0.289375  0.173125   70.754717  53.0082  148.65  48.65  0.0
# 100  0.341250  0.215000   64.903846  46.5288  157.00  59.00  0.0
# 101  0.347500  0.218125   61.538462  46.5288  157.00  59.00  0.0
# 102  0.354375  0.220625   59.850374  46.5288  157.00  59.00  0.0
#
# [103 rows x 14 columns]

# %% [markdown]
# # 새 섹션

# %%
df_test_raw = pd.DataFrame(X_test)
df_test_raw
# Out:
#                0         1         2         3         4         5         6   \
# 0      244.551045  0.158750  0.541875  0.432500  0.171875  0.072500  0.535625
# 1      251.247886  0.166250  0.555000  0.431250  0.175000  0.075000  0.540000
# 2      231.710267  0.193750  0.532500  0.401250  0.146250  0.071250  0.518125
# 3      221.664035  0.195625  0.533750  0.230000  0.138750  0.070000  0.353125
# 4      227.446045  0.199375  0.531875  0.391875  0.150625  0.072500  0.508125
# ...           ...       ...       ...       ...       ...       ...       ...
# 61892  290.873860  0.195000  0.563750  0.432500  0.255000  0.111250  0.555000
# 61893  305.386505  0.201875  0.598750  0.438125  0.281875  0.114375  0.572500
# 61894  302.774386  0.221250  0.593750  0.433750  0.285625  0.116875  0.570625
# 61895  314.019674  0.205000  0.613750  0.437500  0.302500  0.120000  0.577500
# 61896  313.854775  0.211875  0.623750  0.437500  0.305000  0.128750  0.577500
#
#              7         8          9        10     11    12   13
# 0      0.248750  0.127500  87.804878  18.1014  160.2  46.3  0.0
# 1      0.256250  0.133750  84.832905  18.1014  160.2  46.3  0.0
# 2      0.239375  0.132500  84.705882  18.1014  160.2  46.3  0.0
# 3      0.228125  0.132500  84.905660  18.1014  160.2  46.3  0.0
# 4      0.240625  0.135000  84.309133  18.1014  160.2  46.3  0.0
# ...         ...       ...        ...      ...    ...   ...  ...
# 61892  0.352500  0.181250  81.280788  70.0000  149.1  49.8  0.0
# 61893  0.385000  0.186250  76.530612  70.0000  149.1  49.8  0.0
# 61894  0.390000  0.188125  76.142132  70.0000  149.1  49.8  0.0
# 61895  0.402500  0.195000  75.000000  70.0000  149.1  49.8  0.0
# 61896  0.409375  0.203125  74.074074  70.0000  149.1  49.8  0.0
#
# [61897 rows x 14 columns]

# %%
df_sbp_train_raw = pd.DataFrame(sbp_train)
df_sbp_train_raw
# Out:
#                  0
# 0       135.775211
# 1       179.325361
# 2       179.186643
# 3       170.764167
# 4       157.368326
# ...            ...
# 241246   97.332018
# 241247   98.070315
# 241248   97.253163
# 241249   97.532775
# 241250   97.313890
#
# [241251 rows x 1 columns]

# %%
df_sbp_test_raw = pd.DataFrame(sbp_test)
df_sbp_test_raw
# Out:
#                 0
# 0      129.317261
# 1      122.939795
# 2      119.407786
# 3      115.714596
# 4      117.881726
# ...           ...
# 61892  122.096567
# 61893  122.236613
# 61894  122.285327
# 61895  121.677324
# 61896  120.691948
#
# [61897 rows x 1 columns]

# %%
df_dbp_train_raw = pd.DataFrame(dbp_train)
df_dbp_train_raw
# Out:
#                  0
# 0        72.061022
# 1        94.966878
# 2       102.733207
# 3        95.009137
# 4        87.878310
# ...            ...
# 241246   60.409130
# 241247   61.291688
# 241248   61.004405
# 241249   61.052105
# 241250   61.257265
#
# [241251 rows x 1 columns]

# %%
df_dbp_test_raw = pd.DataFrame(dbp_test)
df_dbp_test_raw
# Out:
#                0
# 0      70.706313
# 1      68.775737
# 2      67.477237
# 3      66.076806
# 4      67.177870
# ...          ...
# 61892  63.092004
# 61893  62.690702
# 61894  62.474015
# 61895  61.534257
# 61896  60.593192
#
# [61897 rows x 1 columns]

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (241251, 14)
# (61897, 14)

# %%
epoch = 100
learning_rate = 0.001
batch_size = 512
drop_rate = 0.3

# %% [markdown]
# # model 생성

# %%
model = Sequential()

# %%
model.add(Dense(4, input_dim=14))
model.add(BatchNormalization())
model.add(Activation(activation='relu'))

model.add(Dense(4))
model.add(BatchNormalization())
model.add(Activation(activation='relu'))

model.add(Dense(4))
model.add(BatchNormalization())
model.add(Activation(activation='relu'))

model.add(Dense(4))
model.add(BatchNormalization())
model.add(Activation(activation='relu'))

model.add(Dense(4))
model.add(BatchNormalization())
model.add(Activation(activation='relu'))

model.add(Dense(4))
model.add(BatchNormalization())
model.add(Activation(activation='relu'))

model.add(Dense(4))
model.add(BatchNormalization())
model.add(Activation(activation='relu'))

model.add(Dense(4))
model.add(BatchNormalization())
model.add(Activation(activation='relu'))

model.add(Dense(4))
model.add(BatchNormalization())
model.add(Activation(activation='relu'))

# sigmoid를 하면 안됨 
model.add(Dense(1))

# %%
model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(lr=learning_rate))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 4)                 60
#
#  batch_normalization (BatchN  (None, 4)                16
#  ormalization)
#
#  activation (Activation)     (None, 4)                 0
#
#  dense_1 (Dense)             (None, 4)                 20
#
#  batch_normalization_1 (Batc  (None, 4)                16
#  hNormalization)
#
#  activation_1 (Activation)   (None, 4)                 0
#
#  dense_2 (Dense)             (None, 4)                 20
#
#  batch_normalization_2 (Batc  (None, 4)                16
#  hNormalization)
#
#  activation_2 (Activation)   (None, 4)                 0
#
#  dense_3 (Dense)             (None, 4)                 20
#
#  batch_normalization_3 (Batc  (None, 4)                16
#  hNormalization)
#
#  activation_3 (Activation)   (None, 4)                 0
#
#  dense_4 (Dense)             (None, 4)                 20
#
#  batch_normalization_4 (Batc  (None, 4)                16
#  hNormalization)
#
#  activation_4 (Activation)   (None, 4)                 0
#
#  dense_5 (Dense)             (None, 4)                 20
#
#  batch_normalization_5 (Batc  (None, 4)                16
#  hNormalization)
#
#  activation_5 (Activation)   (None, 4)                 0
#
#  dense_6 (Dense)             (None, 4)                 20
#
#  batch_normalization_6 (Batc  (None, 4)                16
#  hNormalization)
#
#  activation_6 (Activation)   (None, 4)                 0
#
#  dense_7 (Dense)             (None, 4)                 20
#
#  batch_normalization_7 (Batc  (None, 4)                16
#  hNormalization)
#
#  activation_7 (Activation)   (None, 4)                 0
#
#  dense_8 (Dense)             (None, 4)                 20
#
#  batch_normalization_8 (Batc  (None, 4)                16
#  hNormalization)
#
#  activation_8 (Activation)   (None, 4)                 0
#
#  dense_9 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 369
# Trainable params: 297
# Non-trainable params: 72
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
history = model.fit(X_train, sbp_train, batch_size = batch_size, epochs = epoch, validation_data = (X_test, sbp_test) )
# Out:
# Epoch 1/100
# 472/472 [==============================] - 7s 8ms/step - loss: 12305.8848 - val_loss: 11998.2637
# Epoch 2/100
# 472/472 [==============================] - 3s 7ms/step - loss: 11198.8828 - val_loss: 10276.4355
# Epoch 3/100
# 472/472 [==============================] - 3s 7ms/step - loss: 9626.2783 - val_loss: 8566.7793
# Epoch 4/100
# 472/472 [==============================] - 3s 7ms/step - loss: 7767.9277 - val_loss: 6611.0620
# Epoch 5/100
# 472/472 [==============================] - 3s 7ms/step - loss: 5868.3438 - val_loss: 4880.5317
# Epoch 6/100
# 472/472 [==============================] - 3s 7ms/step - loss: 4110.1802 - val_loss: 3313.7935
# Epoch 7/100
# 472/472 [==============================] - 3s 7ms/step - loss: 2638.1748 - val_loss: 2045.1206
# Epoch 8/100
# 472/472 [==============================] - 3s 7ms/step - loss: 1541.0883 - val_loss: 1009.7495
# Epoch 9/100
# 472/472 [==============================] - 3s 7ms/step - loss: 850.5409 - val_loss: 917.5398
# Epoch 10/100
# 472/472 [==============================] - 4s 8ms/step - loss: 501.8507 - val_loss: 447.7278
# Epoch 11/100
# 472/472 [==============================] - 3s 7ms/step - loss: 359.7659 - val_loss: 346.7865
# Epoch 12/100
# 472/472 [==============================] - 3s 7ms/step - loss: 321.9769 - val_loss: 301.6137
# Epoch 13/100
# 472/472 [==============================] - 3s 7ms/step - loss: 314.8941 - val_loss: 305.9882
# Epoch 14/100
# 472/472 [==============================] - 3s 7ms/step - loss: 315.0396 - val_loss: 302.5098
# Epoch 15/100
# 472/472 [==============================] - 3s 7ms/step - loss: 314.5260 - val_loss: 301.4150
# Epoch 16/100
# 472/472 [==============================] - 4s 8ms/step - loss: 313.5548 - val_loss: 301.5370
# Epoch 17/100
# 472/472 [==============================] - 3s 7ms/step - loss: 313.0481 - val_loss: 296.3757
# Epoch 18/100
# 472/472 [==============================] - 3s 7ms/step - loss: 313.6044 - val_loss: 297.7301
# Epoch 19/100
# 472/472 [==============================] - 3s 7ms/step - loss: 314.1604 - val_loss: 297.8992
# Epoch 20/100
# 472/472 [==============================] - 3s 7ms/step - loss: 313.0833 - val_loss: 302.6422
# Epoch 21/100
# 472/472 [==============================] - 3s 7ms/step - loss: 312.8393 - val_loss: 297.7794
# Epoch 22/100
# 472/472 [==============================] - 3s 7ms/step - loss: 312.9546 - val_loss: 295.9103
# Epoch 23/100
# 472/472 [==============================] - 3s 7ms/step - loss: 312.1142 - val_loss: 295.0290
# Epoch 24/100
# 472/472 [==============================] - 3s 7ms/step - loss: 311.5108 - val_loss: 294.9530
# Epoch 25/100
# 472/472 [==============================] - 3s 7ms/step - loss: 311.5653 - val_loss: 297.4526
# Epoch 26/100
# 472/472 [==============================] - 4s 8ms/step - loss: 311.6431 - val_loss: 296.7560
# Epoch 27/100
# 472/472 [==============================] - 4s 7ms/step - loss: 312.0958 - val_loss: 298.4238
# Epoch 28/100
# 472/472 [==============================] - 3s 7ms/step - loss: 311.2216 - val_loss: 293.6427
# Epoch 29/100
# 472/472 [==============================] - 3s 7ms/step - loss: 310.6581 - val_loss: 294.5014
# Epoch 30/100
# 472/472 [==============================] - 3s 7ms/step - loss: 310.5665 - val_loss: 294.2477
# Epoch 31/100
# 472/472 [==============================] - 3s 7ms/step - loss: 310.7107 - val_loss: 295.6489
# Epoch 32/100
# 472/472 [==============================] - 3s 7ms/step - loss: 310.8581 - val_loss: 296.7444
# Epoch 33/100
# 472/472 [==============================] - 3s 7ms/step - loss: 310.9324 - val_loss: 293.4559
# Epoch 34/100
# 472/472 [==============================] - 3s 7ms/step - loss: 310.7046 - val_loss: 295.7968
# Epoch 35/100
# 472/472 [==============================] - 3s 7ms/step - loss: 310.3627 - val_loss: 297.5431
# Epoch 36/100
# 472/472 [==============================] - 3s 7ms/step - loss: 309.6325 - val_loss: 294.1265
# Epoch 37/100
# 472/472 [==============================] - 3s 7ms/step - loss: 309.2139 - val_loss: 297.2952
# Epoch 38/100
# 472/472 [==============================] - 3s 7ms/step - loss: 307.3499 - val_loss: 297.3372
# Epoch 39/100
# 472/472 [==============================] - 3s 7ms/step - loss: 306.0253 - val_loss: 298.8141
# Epoch 40/100
# 472/472 [==============================] - 3s 7ms/step - loss: 304.6334 - val_loss: 301.4639
# Epoch 41/100
# 472/472 [==============================] - 3s 7ms/step - loss: 302.8680 - val_loss: 292.2944
# Epoch 42/100
# 472/472 [==============================] - 3s 7ms/step - loss: 298.4277 - val_loss: 301.7452
# Epoch 43/100
# 472/472 [==============================] - 3s 7ms/step - loss: 293.1194 - val_loss: 315.0823
# Epoch 44/100
# 472/472 [==============================] - 3s 7ms/step - loss: 286.1423 - val_loss: 273.8546
# Epoch 45/100
# 472/472 [==============================] - 3s 7ms/step - loss: 283.3323 - val_loss: 279.5312
# Epoch 46/100
# 472/472 [==============================] - 4s 7ms/step - loss: 281.2793 - val_loss: 282.1993
# Epoch 47/100
# 472/472 [==============================] - 4s 8ms/step - loss: 278.7766 - val_loss: 258.7090
# Epoch 48/100
# 472/472 [==============================] - 3s 7ms/step - loss: 278.2912 - val_loss: 275.1472
# Epoch 49/100
# 472/472 [==============================] - 3s 7ms/step - loss: 278.2121 - val_loss: 263.5774
# Epoch 50/100
# 472/472 [==============================] - 3s 7ms/step - loss: 277.0141 - val_loss: 271.6117
# Epoch 51/100
# 472/472 [==============================] - 3s 7ms/step - loss: 275.9196 - val_loss: 264.7839
# Epoch 52/100
# 472/472 [==============================] - 3s 7ms/step - loss: 274.6089 - val_loss: 263.2499
# Epoch 53/100
# 472/472 [==============================] - 3s 7ms/step - loss: 273.5485 - val_loss: 259.3893
# Epoch 54/100
# 472/472 [==============================] - 3s 7ms/step - loss: 273.2721 - val_loss: 256.7829
# Epoch 55/100
# 472/472 [==============================] - 3s 7ms/step - loss: 272.9626 - val_loss: 261.8443
# Epoch 56/100
# 472/472 [==============================] - 3s 7ms/step - loss: 270.8242 - val_loss: 277.6191
# Epoch 57/100
# 472/472 [==============================] - 3s 7ms/step - loss: 270.3033 - val_loss: 255.6333
# Epoch 58/100
# 472/472 [==============================] - 3s 7ms/step - loss: 269.3778 - val_loss: 261.6121
# Epoch 59/100
# 472/472 [==============================] - 3s 7ms/step - loss: 268.4806 - val_loss: 254.7144
# Epoch 60/100
# 472/472 [==============================] - 3s 7ms/step - loss: 268.0742 - val_loss: 264.9736
# Epoch 61/100
# 472/472 [==============================] - 4s 8ms/step - loss: 267.3660 - val_loss: 251.5586
# Epoch 62/100
# 472/472 [==============================] - 3s 7ms/step - loss: 266.8730 - val_loss: 253.8638
# Epoch 63/100
# 472/472 [==============================] - 3s 7ms/step - loss: 266.1141 - val_loss: 251.9772
# Epoch 64/100
# 472/472 [==============================] - 3s 7ms/step - loss: 265.9701 - val_loss: 254.0781
# Epoch 65/100
# 472/472 [==============================] - 3s 7ms/step - loss: 265.5566 - val_loss: 251.2336
# Epoch 66/100
# 472/472 [==============================] - 4s 7ms/step - loss: 264.8697 - val_loss: 250.5562
# Epoch 67/100
# 472/472 [==============================] - 3s 7ms/step - loss: 265.0511 - val_loss: 275.1595
# Epoch 68/100
# 472/472 [==============================] - 3s 7ms/step - loss: 264.5368 - val_loss: 262.7674
# Epoch 69/100
# 472/472 [==============================] - 3s 7ms/step - loss: 264.2777 - val_loss: 260.7908
# Epoch 70/100
# 472/472 [==============================] - 3s 7ms/step - loss: 264.0814 - val_loss: 250.5892
# Epoch 71/100
# 472/472 [==============================] - 3s 7ms/step - loss: 264.8141 - val_loss: 253.8962
# Epoch 72/100
# 472/472 [==============================] - 3s 7ms/step - loss: 264.4899 - val_loss: 251.2733
# Epoch 73/100
# 472/472 [==============================] - 3s 7ms/step - loss: 264.6462 - val_loss: 250.8766
# Epoch 74/100
# 472/472 [==============================] - 3s 7ms/step - loss: 264.1527 - val_loss: 250.9380
# Epoch 75/100
# 472/472 [==============================] - 3s 7ms/step - loss: 264.1633 - val_loss: 251.5418
# Epoch 76/100
# 472/472 [==============================] - 3s 7ms/step - loss: 263.9837 - val_loss: 258.1683
# Epoch 77/100
# 472/472 [==============================] - 3s 7ms/step - loss: 263.1353 - val_loss: 252.9793
# Epoch 78/100
# 472/472 [==============================] - 3s 7ms/step - loss: 263.2224 - val_loss: 248.6369
# Epoch 79/100
# 472/472 [==============================] - 3s 7ms/step - loss: 262.9994 - val_loss: 254.7059
# Epoch 80/100
# 472/472 [==============================] - 3s 7ms/step - loss: 263.4376 - val_loss: 252.5709
# Epoch 81/100
# 472/472 [==============================] - 3s 7ms/step - loss: 263.1183 - val_loss: 250.0222
# Epoch 82/100
# 472/472 [==============================] - 3s 7ms/step - loss: 262.9667 - val_loss: 256.6168
# Epoch 83/100
# 472/472 [==============================] - 3s 7ms/step - loss: 263.1028 - val_loss: 247.2404
# Epoch 84/100
# 472/472 [==============================] - 3s 7ms/step - loss: 262.9611 - val_loss: 253.4548
# Epoch 85/100
# 472/472 [==============================] - 3s 7ms/step - loss: 263.3584 - val_loss: 251.4739
# Epoch 86/100
# 472/472 [==============================] - 3s 7ms/step - loss: 262.7629 - val_loss: 249.4678
# Epoch 87/100
# 472/472 [==============================] - 3s 7ms/step - loss: 262.5203 - val_loss: 249.4334
# Epoch 88/100
# 472/472 [==============================] - 3s 7ms/step - loss: 262.5369 - val_loss: 251.3154
# Epoch 89/100
# 472/472 [==============================] - 3s 7ms/step - loss: 262.3518 - val_loss: 272.2209
# Epoch 90/100
# 472/472 [==============================] - 3s 7ms/step - loss: 262.1753 - val_loss: 246.1440
# Epoch 91/100
# 472/472 [==============================] - 3s 7ms/step - loss: 262.0682 - val_loss: 260.5464
# Epoch 92/100
# 472/472 [==============================] - 3s 7ms/step - loss: 262.5514 - val_loss: 245.6946
# Epoch 93/100
# 472/472 [==============================] - 3s 7ms/step - loss: 262.1164 - val_loss: 245.5290
# Epoch 94/100
# 472/472 [==============================] - 3s 7ms/step - loss: 261.9355 - val_loss: 245.6490
# Epoch 95/100
# 472/472 [==============================] - 3s 7ms/step - loss: 262.0770 - val_loss: 256.3573
# Epoch 96/100
# 472/472 [==============================] - 3s 7ms/step - loss: 261.7891 - val_loss: 248.8747
# Epoch 97/100
# 472/472 [==============================] - 3s 7ms/step - loss: 261.6774 - val_loss: 248.9918
# Epoch 98/100
# 472/472 [==============================] - 3s 7ms/step - loss: 261.7729 - val_loss: 247.3067
# Epoch 99/100
# 472/472 [==============================] - 3s 7ms/step - loss: 261.6278 - val_loss: 256.5818
# Epoch 100/100
# 472/472 [==============================] - 3s 7ms/step - loss: 261.5642 - val_loss: 253.3187

# %%
pred = model.predict(X_test)

err = sbp_test - pred
me = np.mean(err)
mae = np.mean(abs(err))
std = np.std(err)

# 오차의 평균 낮으면 좋다 , std 오차들의 표준편차 작으면 좋다
# 앙상블 개념 익히기
# total_me = total_me + me
# total_std = total_std + std

# me: 5, std: 8

# 현재 값

# ME:  2.0595606447151926 
# MAE:  12.274325409297312 
# SD:  15.782171026164185

print("\nME: ", me, "\nMAE: ", mae,"\nSD: ", std)
# Out:
# ME:  2.0595606447151926
# MAE:  12.274325409297312
# SD:  15.782171026164185

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.ylim([0, 1000])  
plt.legend(['train','val'])
plt.show()
